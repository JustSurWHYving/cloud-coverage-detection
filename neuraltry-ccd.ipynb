# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/kaggle/input/cloud-coverage-detection/train.csv', low_memory=False)

# %%
df.head()
# Out:
#   DATE (MM/DD)    MST  Global CMP22 (vent/cor) [W/m^2]  Direct sNIP [W/m^2]  \
# 0       01-Jan  00:00                        -0.962276             0.000000
# 1       01-Jan  00:01                        -0.937921             0.000000
# 2       01-Jan  00:02                        -0.944395             0.000000
# 3       01-Jan  00:03                        -0.951350            -0.029673
# 4       01-Jan  00:04                        -0.934976            -0.054401
#
#    Azimuth Angle [degrees]  Tower Dry Bulb Temp [deg C]  \
# 0                356.85640                        7.216
# 1                357.65505                        7.251
# 2                358.45438                        7.256
# 3                359.25416                        7.254
# 4                  0.05415                        7.331
#
#    Tower Wet Bulb Temp [deg C]  Tower Dew Point Temp [deg C]  Tower RH [%]  \
# 0                        0.988                        -7.312         32.33
# 1                        1.040                        -7.260         32.40
# 2                        1.093                        -7.207         32.54
# 3                        1.060                        -7.440         31.89
# 4                        1.081                        -7.419         31.78
#
#    Total Cloud Cover [%]  Peak Wind Speed @ 6ft [m/s]  \
# 0                    0.0                         9.95
# 1                    0.0                         8.20
# 2                    0.0                         6.70
# 3                    0.0                         7.70
# 4                    0.0                         7.20
#
#    Avg Wind Direction @ 6ft [deg from N]  Station Pressure [mBar]  \
# 0                                  271.3                  806.779
# 1                                  272.9                  806.840
# 2                                  288.8                  806.876
# 3                                  294.0                  806.823
# 4                                  285.5                  806.762
#
#    Precipitation (Accumulated) [mm]  Snow Depth [cm]  Moisture  Albedo (CMP11)
# 0                               0.0            0.219       0.0             0.0
# 1                               0.0            0.206       0.0             0.0
# 2                               0.0            0.148       0.0             0.0
# 3                               0.0            0.235       0.0             0.0
# 4                               0.0            0.182       0.0             0.0

# %%
df.drop(columns=['MST' , 'DATE (MM/DD)'],inplace=True)
df.head()
# Out:
#    Global CMP22 (vent/cor) [W/m^2]  Direct sNIP [W/m^2]  \
# 0                        -0.962276             0.000000
# 1                        -0.937921             0.000000
# 2                        -0.944395             0.000000
# 3                        -0.951350            -0.029673
# 4                        -0.934976            -0.054401
#
#    Azimuth Angle [degrees]  Tower Dry Bulb Temp [deg C]  \
# 0                356.85640                        7.216
# 1                357.65505                        7.251
# 2                358.45438                        7.256
# 3                359.25416                        7.254
# 4                  0.05415                        7.331
#
#    Tower Wet Bulb Temp [deg C]  Tower Dew Point Temp [deg C]  Tower RH [%]  \
# 0                        0.988                        -7.312         32.33
# 1                        1.040                        -7.260         32.40
# 2                        1.093                        -7.207         32.54
# 3                        1.060                        -7.440         31.89
# 4                        1.081                        -7.419         31.78
#
#    Total Cloud Cover [%]  Peak Wind Speed @ 6ft [m/s]  \
# 0                    0.0                         9.95
# 1                    0.0                         8.20
# 2                    0.0                         6.70
# 3                    0.0                         7.70
# 4                    0.0                         7.20
#
#    Avg Wind Direction @ 6ft [deg from N]  Station Pressure [mBar]  \
# 0                                  271.3                  806.779
# 1                                  272.9                  806.840
# 2                                  288.8                  806.876
# 3                                  294.0                  806.823
# 4                                  285.5                  806.762
#
#    Precipitation (Accumulated) [mm]  Snow Depth [cm]  Moisture  Albedo (CMP11)
# 0                               0.0            0.219       0.0             0.0
# 1                               0.0            0.206       0.0             0.0
# 2                               0.0            0.148       0.0             0.0
# 3                               0.0            0.235       0.0             0.0
# 4                               0.0            0.182       0.0             0.0

# %%
df['sin(Azimuth)'] = np.sin(np.radians(df['Azimuth Angle [degrees]']))
df['cos(Azimuth)'] = np.cos(np.radians(df['Azimuth Angle [degrees]']))

df.drop(columns=['Azimuth Angle [degrees]'], inplace=True)

print(df.head())
# Out:
#    Global CMP22 (vent/cor) [W/m^2]  Direct sNIP [W/m^2]  \
# 0                        -0.962276             0.000000
# 1                        -0.937921             0.000000
# 2                        -0.944395             0.000000
# 3                        -0.951350            -0.029673
# 4                        -0.934976            -0.054401
#
#    Tower Dry Bulb Temp [deg C]  Tower Wet Bulb Temp [deg C]  \
# 0                        7.216                        0.988
# 1                        7.251                        1.040
# 2                        7.256                        1.093
# 3                        7.254                        1.060
# 4                        7.331                        1.081
#
#    Tower Dew Point Temp [deg C]  Tower RH [%]  Total Cloud Cover [%]  \
# 0                        -7.312         32.33                    0.0
# 1                        -7.260         32.40                    0.0
# 2                        -7.207         32.54                    0.0
# 3                        -7.440         31.89                    0.0
# 4                        -7.419         31.78                    0.0
#
#    Peak Wind Speed @ 6ft [m/s]  Avg Wind Direction @ 6ft [deg from N]  \
# 0                         9.95                                  271.3
# 1                         8.20                                  272.9
# 2                         6.70                                  288.8
# 3                         7.70                                  294.0
# 4                         7.20                                  285.5
#
#    Station Pressure [mBar]  Precipitation (Accumulated) [mm]  Snow Depth [cm]  \
# 0                  806.779                               0.0            0.219
# 1                  806.840                               0.0            0.206
# 2                  806.876                               0.0            0.148
# 3                  806.823                               0.0            0.235
# 4                  806.762                               0.0            0.182
#
#    Moisture  Albedo (CMP11)  sin(Azimuth)  cos(Azimuth)
# 0       0.0             0.0     -0.054839      0.998495
# 1       0.0             0.0     -0.040916      0.999163
# 2       0.0             0.0     -0.026973      0.999636
# 3       0.0             0.0     -0.013017      0.999915
# 4       0.0             0.0      0.000945      1.000000

# %%
df=df.iloc[:-30000, :]
df
# Out:
#         Global CMP22 (vent/cor) [W/m^2]  Direct sNIP [W/m^2]  \
# 0                             -0.962276             0.000000
# 1                             -0.937921             0.000000
# 2                             -0.944395             0.000000
# 3                             -0.951350            -0.029673
# 4                             -0.934976            -0.054401
# ...                                 ...                  ...
# 497035                        -0.971774            -0.696220
# 497036                        -0.979429            -0.720908
# 497037                        -0.992569            -0.760409
# 497038                        -1.005990            -0.785097
# 497039                        -1.000040            -0.770283
#
#         Tower Dry Bulb Temp [deg C]  Tower Wet Bulb Temp [deg C]  \
# 0                             7.216                        0.988
# 1                             7.251                        1.040
# 2                             7.256                        1.093
# 3                             7.254                        1.060
# 4                             7.331                        1.081
# ...                             ...                          ...
# 497035                       -4.293                       -4.311
# 497036                       -4.301                       -4.331
# 497037                       -4.315                       -4.345
# 497038                       -4.314                       -4.332
# 497039                       -4.313                       -4.331
#
#         Tower Dew Point Temp [deg C]  Tower RH [%]  Total Cloud Cover [%]  \
# 0                             -7.312         32.33                    0.0
# 1                             -7.260         32.40                    0.0
# 2                             -7.207         32.54                    0.0
# 3                             -7.440         31.89                    0.0
# 4                             -7.419         31.78                    0.0
# ...                              ...           ...                    ...
# 497035                        -4.411         99.00                    0.0
# 497036                        -4.431         98.90                    0.0
# 497037                        -4.445         98.90                    0.0
# 497038                        -4.432         99.00                    0.0
# 497039                        -4.431         99.00                    0.0
#
#         Peak Wind Speed @ 6ft [m/s]  Avg Wind Direction @ 6ft [deg from N]  \
# 0                              9.95                                 271.30
# 1                              8.20                                 272.90
# 2                              6.70                                 288.80
# 3                              7.70                                 294.00
# 4                              7.20                                 285.50
# ...                             ...                                    ...
# 497035                         1.20                                  58.17
# 497036                         1.20                                  65.84
# 497037                         0.95                                  62.73
# 497038                         0.95                                  72.58
# 497039                         1.45                                  68.96
#
#         Station Pressure [mBar]  Precipitation (Accumulated) [mm]  \
# 0                       806.779                               0.0
# 1                       806.840                               0.0
# 2                       806.876                               0.0
# 3                       806.823                               0.0
# 4                       806.762                               0.0
# ...                         ...                               ...
# 497035                  811.758                               0.0
# 497036                  811.726                               0.0
# 497037                  811.704                               0.0
# 497038                  811.687                               0.0
# 497039                  811.657                               0.0
#
#         Snow Depth [cm]  Moisture  Albedo (CMP11)  sin(Azimuth)  cos(Azimuth)
# 0                 0.219       0.0             0.0     -0.054839      0.998495
# 1                 0.206       0.0             0.0     -0.040916      0.999163
# 2                 0.148       0.0             0.0     -0.026973      0.999636
# 3                 0.235       0.0             0.0     -0.013017      0.999915
# 4                 0.182       0.0             0.0      0.000945      1.000000
# ...                 ...       ...             ...           ...           ...
# 497035            0.864       1.0             0.0      0.999939     -0.011082
# 497036            0.831       1.0             0.0      0.999904     -0.013840
# 497037            0.859       1.0             0.0      0.999862     -0.016591
# 497038            0.879       1.0             0.0      0.999813     -0.019336
# 497039            0.839       1.0             0.0      0.999756     -0.022074
#
# [497040 rows x 16 columns]

# %%
df_cleaned = df.dropna(subset=['Total Cloud Cover [%]'])

df_ffill = df_cleaned.fillna(method='ffill')

df_imputed = df_ffill.fillna(method='bfill')
remaining_missing_values = df_imputed.isna().sum()
print("Remaining missing values :")
print(remaining_missing_values)
# Out:
# Remaining missing values :
# Global CMP22 (vent/cor) [W/m^2]          0
# Direct sNIP [W/m^2]                      0
# Tower Dry Bulb Temp [deg C]              0
# Tower Wet Bulb Temp [deg C]              0
# Tower Dew Point Temp [deg C]             0
# Tower RH [%]                             0
# Total Cloud Cover [%]                    0
# Peak Wind Speed @ 6ft [m/s]              0
# Avg Wind Direction @ 6ft [deg from N]    0
# Station Pressure [mBar]                  0
# Precipitation (Accumulated) [mm]         0
# Snow Depth [cm]                          0
# Moisture                                 0
# Albedo (CMP11)                           0
# sin(Azimuth)                             0
# cos(Azimuth)                             0
# dtype: int64
# /tmp/ipykernel_34/1351208147.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_ffill = df_cleaned.fillna(method='ffill')
# /tmp/ipykernel_34/1351208147.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_imputed = df_ffill.fillna(method='bfill')

# %%
df_imputed.head()
# Out:
#    Global CMP22 (vent/cor) [W/m^2]  Direct sNIP [W/m^2]  \
# 0                        -0.962276             0.000000
# 1                        -0.937921             0.000000
# 2                        -0.944395             0.000000
# 3                        -0.951350            -0.029673
# 4                        -0.934976            -0.054401
#
#    Tower Dry Bulb Temp [deg C]  Tower Wet Bulb Temp [deg C]  \
# 0                        7.216                        0.988
# 1                        7.251                        1.040
# 2                        7.256                        1.093
# 3                        7.254                        1.060
# 4                        7.331                        1.081
#
#    Tower Dew Point Temp [deg C]  Tower RH [%]  Total Cloud Cover [%]  \
# 0                        -7.312         32.33                    0.0
# 1                        -7.260         32.40                    0.0
# 2                        -7.207         32.54                    0.0
# 3                        -7.440         31.89                    0.0
# 4                        -7.419         31.78                    0.0
#
#    Peak Wind Speed @ 6ft [m/s]  Avg Wind Direction @ 6ft [deg from N]  \
# 0                         9.95                                  271.3
# 1                         8.20                                  272.9
# 2                         6.70                                  288.8
# 3                         7.70                                  294.0
# 4                         7.20                                  285.5
#
#    Station Pressure [mBar]  Precipitation (Accumulated) [mm]  Snow Depth [cm]  \
# 0                  806.779                               0.0            0.219
# 1                  806.840                               0.0            0.206
# 2                  806.876                               0.0            0.148
# 3                  806.823                               0.0            0.235
# 4                  806.762                               0.0            0.182
#
#    Moisture  Albedo (CMP11)  sin(Azimuth)  cos(Azimuth)
# 0       0.0             0.0     -0.054839      0.998495
# 1       0.0             0.0     -0.040916      0.999163
# 2       0.0             0.0     -0.026973      0.999636
# 3       0.0             0.0     -0.013017      0.999915
# 4       0.0             0.0      0.000945      1.000000

# %%
import tensorflow as tf
from sklearn.preprocessing import StandardScaler

df_imputed['cloud_cover_15'] = df_imputed['Total Cloud Cover [%]'].shift(-15)
df_imputed['cloud_cover_25'] = df_imputed['Total Cloud Cover [%]'].shift(-25)
df_imputed['cloud_cover_30'] = df_imputed['Total Cloud Cover [%]'].shift(-30)
df_imputed.dropna(inplace=True)

X = df_imputed.drop(columns=['Total Cloud Cover [%]', 'cloud_cover_15', 'cloud_cover_25', 'cloud_cover_30'])
y = df_imputed[['cloud_cover_15', 'cloud_cover_25', 'cloud_cover_30']]

train_size = int(0.9 * len(X))

X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]
 
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(1024, activation='relu'),
    tf.keras.layers.Dense(1024, activation='relu'),
    tf.keras.layers.Dense(1024, activation='relu'),
    tf.keras.layers.Dense(1024, activation='relu'),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(3, activation='linear'),
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=[
                  tf.keras.metrics.MeanAbsoluteError(),
                  tf.keras.metrics.MeanAbsolutePercentageError(),
                  tf.keras.metrics.R2Score()
              ])

model.fit(X_train, y_train, epochs=15, validation_split=0.2)

loss, mae, mape , r2_score= model.evaluate(X_test, y_test)
print(f'Loss: {loss}, MAE: {mae}, MAPE: {mape} , R2_SCORE : {r2_score}')

predictions = model.predict(X_test)

for i in range(5):
    print(f'Predicted: {predictions[i]}, Actual: {y_test.iloc[i].values}')
# Out:
# 2024-06-22 10:56:23.078331: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-22 10:56:23.078435: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-22 10:56:23.216514: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Epoch 1/15
#    44/10794 ━━━━━━━━━━━━━━━━━━━━ 38s 4ms/step - loss: 1243.1788 - mean_absolute_error: 21.9169 - mean_absolute_percentage_error: 3307767552.0000 - r2_score: -0.0090
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1719053800.630406     110 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1719053800.646704     110 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 10794/10794 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 250.6456 - mean_absolute_error: 8.3450 - mean_absolute_percentage_error: 646074944.0000 - r2_score: 0.7993
# W0000 00:00:1719053837.259147     108 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 10794/10794 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - loss: 250.6409 - mean_absolute_error: 8.3449 - mean_absolute_percentage_error: 646065088.0000 - r2_score: 0.7993 - val_loss: 256.2556 - val_mean_absolute_error: 8.3748 - val_mean_absolute_percentage_error: 1086081792.0000 - val_r2_score: 0.7943
# Epoch 2/15
# 10794/10794 ━━━━━━━━━━━━━━━━━━━━ 37s 3ms/step - loss: 142.0508 - mean_absolute_error: 6.1401 - mean_absolute_percentage_error: 455767456.0000 - r2_score: 0.8868 - val_loss: 263.9880 - val_mean_absolute_error: 8.7882 - val_mean_absolute_percentage_error: 1253093760.0000 - val_r2_score: 0.7881
# Epoch 3/15
# 10794/10794 ━━━━━━━━━━━━━━━━━━━━ 37s 3ms/step - loss: 109.1897 - mean_absolute_error: 5.3011 - mean_absolute_percentage_error: 356859712.0000 - r2_score: 0.9131 - val_loss: 342.4042 - val_mean_absolute_error: 9.7530 - val_mean_absolute_percentage_error: 1193774464.0000 - val_r2_score: 0.7252
# Epoch 4/15
# 10794/10794 ━━━━━━━━━━━━━━━━━━━━ 37s 3ms/step - loss: 90.4953 - mean_absolute_error: 4.7755 - mean_absolute_percentage_error: 326773248.0000 - r2_score: 0.9280 - val_loss: 336.1564 - val_mean_absolute_error: 9.6600 - val_mean_absolute_percentage_error: 1423300736.0000 - val_r2_score: 0.7302
# Epoch 5/15
# 10794/10794 ━━━━━━━━━━━━━━━━━━━━ 37s 3ms/step - loss: 77.0198 - mean_absolute_error: 4.3446 - mean_absolute_percentage_error: 292025376.0000 - r2_score: 0.9384 - val_loss: 374.3031 - val_mean_absolute_error: 10.5747 - val_mean_absolute_percentage_error: 2242652928.0000 - val_r2_score: 0.6996
# Epoch 6/15
# 10794/10794 ━━━━━━━━━━━━━━━━━━━━ 38s 3ms/step - loss: 69.5689 - mean_absolute_error: 4.0982 - mean_absolute_percentage_error: 288206080.0000 - r2_score: 0.9443 - val_loss: 358.1804 - val_mean_absolute_error: 10.1113 - val_mean_absolute_percentage_error: 1695564032.0000 - val_r2_score: 0.7125
# Epoch 7/15
# 10794/10794 ━━━━━━━━━━━━━━━━━━━━ 37s 3ms/step - loss: 62.2206 - mean_absolute_error: 3.8542 - mean_absolute_percentage_error: 282876384.0000 - r2_score: 0.9505 - val_loss: 330.3600 - val_mean_absolute_error: 9.4664 - val_mean_absolute_percentage_error: 1364655488.0000 - val_r2_score: 0.7349
# Epoch 8/15
# 10794/10794 ━━━━━━━━━━━━━━━━━━━━ 37s 3ms/step - loss: 57.5294 - mean_absolute_error: 3.6897 - mean_absolute_percentage_error: 275959808.0000 - r2_score: 0.9542 - val_loss: 338.7419 - val_mean_absolute_error: 9.4942 - val_mean_absolute_percentage_error: 1316961664.0000 - val_r2_score: 0.7281
# Epoch 9/15
# 10794/10794 ━━━━━━━━━━━━━━━━━━━━ 37s 3ms/step - loss: 53.3538 - mean_absolute_error: 3.5456 - mean_absolute_percentage_error: 278232096.0000 - r2_score: 0.9574 - val_loss: 404.1901 - val_mean_absolute_error: 10.3787 - val_mean_absolute_percentage_error: 1591606528.0000 - val_r2_score: 0.6756
# Epoch 10/15
# 10794/10794 ━━━━━━━━━━━━━━━━━━━━ 37s 3ms/step - loss: 48.6336 - mean_absolute_error: 3.3784 - mean_absolute_percentage_error: 264919168.0000 - r2_score: 0.9612 - val_loss: 375.1136 - val_mean_absolute_error: 9.9997 - val_mean_absolute_percentage_error: 1170493056.0000 - val_r2_score: 0.6989
# Epoch 11/15
# 10794/10794 ━━━━━━━━━━━━━━━━━━━━ 37s 3ms/step - loss: 45.6916 - mean_absolute_error: 3.2459 - mean_absolute_percentage_error: 252699552.0000 - r2_score: 0.9635 - val_loss: 422.0975 - val_mean_absolute_error: 10.7736 - val_mean_absolute_percentage_error: 1892844672.0000 - val_r2_score: 0.6612
# Epoch 12/15
# 10794/10794 ━━━━━━━━━━━━━━━━━━━━ 37s 3ms/step - loss: 44.0146 - mean_absolute_error: 3.1924 - mean_absolute_percentage_error: 276905984.0000 - r2_score: 0.9650 - val_loss: 364.1787 - val_mean_absolute_error: 9.8831 - val_mean_absolute_percentage_error: 1215553792.0000 - val_r2_score: 0.7077
# Epoch 13/15
# 10794/10794 ━━━━━━━━━━━━━━━━━━━━ 37s 3ms/step - loss: 41.6254 - mean_absolute_error: 3.1077 - mean_absolute_percentage_error: 289833792.0000 - r2_score: 0.9669 - val_loss: 394.0924 - val_mean_absolute_error: 10.1815 - val_mean_absolute_percentage_error: 1044547136.0000 - val_r2_score: 0.6837
# Epoch 14/15
# 10794/10794 ━━━━━━━━━━━━━━━━━━━━ 38s 3ms/step - loss: 41.8157 - mean_absolute_error: 3.0972 - mean_absolute_percentage_error: 324443072.0000 - r2_score: 0.9666 - val_loss: 390.2424 - val_mean_absolute_error: 10.2994 - val_mean_absolute_percentage_error: 1444523008.0000 - val_r2_score: 0.6868
# Epoch 15/15
# 10794/10794 ━━━━━━━━━━━━━━━━━━━━ 38s 3ms/step - loss: 38.9725 - mean_absolute_error: 3.0102 - mean_absolute_percentage_error: 316133856.0000 - r2_score: 0.9689 - val_loss: 399.6292 - val_mean_absolute_error: 10.8230 - val_mean_absolute_percentage_error: 1605784192.0000 - val_r2_score: 0.6793
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 244.0813 - mean_absolute_error: 7.2485 - mean_absolute_percentage_error: 1346901376.0000 - r2_score: 0.6591
# Loss: 188.9581756591797, MAE: 6.316064834594727, MAPE: 1262992896.0 , R2_SCORE : 0.6786081194877625
#  118/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# W0000 00:00:1719054368.912441     108 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Predicted: [0.8821188 1.2690108 2.0345154], Actual: [0. 0. 0.]
# Predicted: [0.8821188 1.2690108 2.0345154], Actual: [0. 0. 0.]
# Predicted: [0.8821188 1.2690108 2.0345154], Actual: [0. 0. 0.]
# Predicted: [0.8821188 1.2690108 2.0345154], Actual: [0. 0. 0.]
# Predicted: [0.8821188 1.2690108 2.0345154], Actual: [0. 0. 0.]

# %%
import matplotlib.pyplot as plt

time_horizons = ['15 minutes', '25 minutes', '30 minutes']
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

for i, ax in enumerate(axes):
    ax.scatter(y_test.iloc[:, i], predictions[:, i], alpha=0.5)
    ax.plot([y_test.iloc[:, i].min(), y_test.iloc[:, i].max()],
            [y_test.iloc[:, i].min(), y_test.iloc[:, i].max()],
            'k--', lw=2)
    ax.set_xlabel('Actual')
    ax.set_ylabel('Predicted')
    ax.set_title(f'Actual vs Predicted ({time_horizons[i]})')

plt.tight_layout()
plt.show()
